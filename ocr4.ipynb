# %%
#OCR 4 (FINAL)


"""List of parameters includes the parameters the OCR will check for in the file add more diseases 
according to the database created"""

"""This automatically detects if the file is a pdf or an image. PDF is handled by pdfocr() and image by imageocr()"""
# Out:
# 'This automatically detects if the file is a pdf or an image. PDF is handled by pdfocr() and image by imageocr()'

# %%
"Library Files"

from pdf2image import convert_from_path
import pytesseract
from PIL import Image
import cv2
import os
import re

# %%
"""List of parameters"""

vitals=("Sugar","(MCV)","Haemoglobin","Cholestrol","Pulse Rate","Total RBC","(PCV)","Platelet Count"," Leucocytes Count","TSH (Thyroid Stimulating Hormone)","Glucose (Random)","Bilirubin Total","PH","WBC")
kidney=("Cretin level","Protein")
stroke=("BP (diastolic)","BP (systolic)","Pulse Rate")
liver=("Bilirubin Total","Bilirubin Direct","Bilirubin Indirect")

# %%
#taking the disease as input
disease=input("Enter The disease whose report you are uploading:-")
# Out:
# Enter The disease whose report you are uploading:-

# %%
def pdfocr(file,disease):
    string=""
    filexp=file.split(".")
    nm=filexp[0]
    i=1
    pages = convert_from_path(file, 500)
    for page in pages:
        name=nm+str(i)+'.jpg'
        page.save(name, 'JPEG')
        i=i+1
    
    j=1
    TEXT=""
    while j<i:
        fileimg = nm+str(j)+'.jpg'
        print(fileimg+" Scanned Successfully")
        img=cv2.imread(fileimg)
        text=pytesseract.image_to_string(img)
        TEXT=TEXT+text
        j=j+1
    
    print(TEXT)
    
    for i in vitals:
        spl_word = i
        if (TEXT.find(spl_word)!=-1):
            res=TEXT.partition(spl_word)[-1]
            res=res.split()
            string=res[0]
            if re.match('\d*\.?\d+',string):
                data.append(string)
            else:
                data.append('0')
        else:
            data.append('0')
        
    if disease=="Kidney" or disease=='kidney':
        for i in kidney:
            #print(i)
            spl_word=i
            res=text.partition(spl_word)[-1]
            res=res.split()
            string=res[0]
            data.append(string)
        
    elif disease=="Stroke" or disease=="stroke":
        for i in stroke:
            #print(i)
            spl_word=i
            res=text.partition(spl_word)[-1]
            res=res.split()
            string=res[0]
            data.append(string)
    elif disease=="Liver" or disease=="liver":
        for i in liver:
            #print(i)
            spl_word=i
            res=text.partition(spl_word)[-1]
            res=res.split()
            string=res[0]
            data.append(string)
    else:
        print("Vitals Only")
            
    return data

# %%
def imageocr(file,disease):
    print("Image OCR")

# %%
#Upload the file
file=input("Enter the file name= ")

expand=file.split(".")

data=[]

if expand[1]=="pdf":
    data=pdfocr(file,disease)
    
else:
    data=imgocr(file,disease)
    
print(data)
# Out:
# Enter the file name= deepa_mukherjee.pdf
# deepa_mukherjee1.jpg Scanned Successfully
# deepa_mukherjee2.jpg Scanned Successfully
# deepa_mukherjee3.jpg Scanned Successfully
# deepa_mukherjee4.jpg Scanned Successfully
# deepa_mukherjee5.jpg Scanned Successfully
# 0000001210495
#
#
#
# GENERAL DIAGNOSTICS
#
#
#
# Preventing Litenre Prt toa. | ESRERSPRECEREN | 5
# RPT House, Plot No. 6, Sec-24, alate Re DIAGNOSTICS
# Turbhe, Navi Mumbai-400705, A PreventiNe Life Care enterprise
# Phone No: 022-4045-0000
#
# Names DEEPA MUKHARJEE Age/Gender: 20 Year(s) 0 Months(s) 0
#
# Day(s)/Female
# Referred By: BHARAT AGARWAL Client Name: DER MED CLINIC
# Collection Date: 29-09-2019 11:03:00 Report Release Date: 29-09-2019
#
# Investigation
#
# Observed Value
#
# Reference Range
#
#
#
# Complete Haemogram Test
#
# Erythrocytes
# 1 Total RBC 5.28 4.1-5.1 1046/pL
# 2 Hemoglobin 12.9 12.3-15.3 g/dL
# 3 Hematocrit (PCV) 41.0 33-57 %
# 4 Mean Corpuscular Volume (MCV) 77.6 80-96 fL
# 5 Mean Corpuscular Hemoglobin (MCH) 24.4 27.5-33.2 pg
# 6 Mean Corpuscular Hemoglobin Concentration 31.5 29.4- 34.5 g/dL
# (MCHC)
# Red Cell Distribution Width (RDW-CV) 16.6 12-15 %
# Red Cell Distribution Width-SD(RDW-SD) 44.2 32-60.4 %
# 9 Nucleated Red Blood Cells 0.0 0 - 1.36 cells/uL
# 10  Nucleated Red Blood Cells Percentage 0.0 0-4 %
# Platelets
# 11 Platelet Count 282.0 150-450 10?/uL
# 12. Mean Platelet Volume (MPV) 9.0 6-12 fL
# 13. _— Platelet Distribution Width (PDW) 16.9 15.5-18.3 %
# 14 ~~ Plateletcrit (PCT) 0.253 0.12-0.37 %
# Leucocytes
# 15 = Total Leucocytes Count 5.1 4.4-1] 1049/L
# 16 Neutrophils 58.0 40-77 %
# 17 Lymphocyte Percentage 31.3 16-44 %
# 18 Monocytes Percentage 7.7 2.0-10.0 %
# 19 Eosinophils Percentage 2.9 0-7 %
# 20 ~~ Basophils Percentage 0.1 0-1 %
# 21 Neutrophils-Absolute Count 2.96 1.8-7.8 1049/L
# 22 Lymphocytes-Absolute Count 1.60 1-4.8 1049/L
# 23. Monocytes-Absolute Count 0.39 0.1-1.0 1049/L
# 24 ~—_Eosinophils-Absolute Count 0.15 0-0.45 10°9/L
# 25 Basophils-Absolute Count 0.01 0-0.2 1049/L
# The analyte is notin the lab scope. Er out
# Sample Received Time: 29-09-2019 11:08:26 Authorized Signatory Authorized Signatory
# Report Release Date: 29-09-2019 Dr. Dina Abhani Dr. Mahesh Hampe
# Patient Name: DEEPA MUKHARJEE DCP, DNB (Pathology) MD (Biochemistry) Page 1 of 5
#
# Patient ID: 1210495
# To view your report, log in www.preventine.org/reports. Feed your Patient ID to download your report.0000001210495
#
#
#
# GENERAL DIAGNOSTICS
#
# Preventine Lifecare Pvt. Ltd. || Pobope eens cell |
#
# RPT House, Plot No. 6, Sec-24,
# Turbhe, Navi Mumbai-400705,
#
# Phone No: 022-4045-0000
#
# Name:
#
# Referred By:
#
# Collection Date:
#
#
#
# b DIAGNOSTICS
# A PreventiNe Life Care enterprise
# DEEPA MUKHARJEE Age/Gender: 20 Year(s) 0 Months(s) 0
# Day(s)/Female
# BHARAT AGARWAL Client Name: DER MED CLINIC
# 29-09-2019 11:03:00 Report Release Date: 29-09-2019
#
# Investigation Observed Value Reference Range
#
#
#
# Pheripheral Blood Smear
#
# 26 RBC Morphology Normocytic
# Normochromic
# 27 = WBC Morphology Within Normal
# Range
# 28 Platelets Adequate On
# Smear
# * The analyte is not in the lab scope. DEK : c
# CRM No :1210495 ee a
# Sample Received Time: 29-09-2019 11:08:26 Authorized Signatory Authorized Signatory
# Report Release Date: 29-09-2019 Dr. Dina Abhani Dr. Mahesh Hampe
# Patient Name: DEEPA MUKHARJEE DCP, DNB (Pathology) MD (Biochemistry) Page 2 of 5
#
# Patient ID: 1210495
#
# To view your report, log in www.preventine.org/reports. Feed your Patient ID to download your report.0000001210495
#
# GENERAL DIAGNOSTICS
# Preventine Lifecare Pvt. Ltd.
# RPT House, Plot No. 6, Sec-24,
#
# Turbhe, Navi Mumbai-400705,
# Phone No: 022-4045-0000
#
# Name: DEEPA MUKHARJEE
# Referred By: BHARAT AGARWAL
# Collection Date: 29-09-2019 11:03:00
#
# Sees oecell|
#
# & DIAGNOSTICS
#
# A PreventiNe Life Care enterprise
#
#
#
# ; 20 Year(s) 0 Months(s) 0
# Age/Gender: Day(s)/Female
# Client Name: DER MED CLINIC
# Report Release Date: 29-09-2019
#
# Observed Value
#
#
#
# Investigation
#
# Creatinine
#
# 1 Creatinine
# Serum, Method: Alkaline picrate kinetic
#
# Interpretation
#
# Reference Range
#
# 0.71 0.4-1.2 mg/dL
#
# Creatinine is a waste product produced by muscles from the breakdown of a compound called creatine. Creatinine is removed
# from the body by the kidneys, which filter almost all of it from the blood and release it into the urine. Increased creatinine levels
# in the blood suggest kidney disease or other conditions that affect kidney function. Low blood levels of creatinine are not
# common, but they are also not usually a cause for concern. They can be seen with conditions that result 1n decreased muscle
#
# mass.
#
# * The analyte is not in the lab scope.
# CRM No :1210495
#
# Sample Received Time: 29-09-2019 11:08:26
# Report Release Date: 29-09-2019
#
# Patient Name: DEEPA MUKHARJEE
# Patient ID: 1210495
#
# pee out t_
#
# Authorized Signatory Authorized Signatory
# Dr. Dina Abhani Dr. Mahesh Hampe
# DCP, DNB (Pathology) MD (Biochemistry) Page 3 of 5
#
# To view your report, log in www.preventine.org/reports. Feed your Patient ID to download your report.0000001210495
#
#
#
#
#
# GENERAL DIAGNOSTICS ;
# Preventine Lifecare Pvt. Ltd. || Pobope eens cell |
# RPT House, Plot No. 6, Sec-24, nas
#
# Turbhe, Navi Mumbai-400705,
#
# Phone No: 022-4045-0000
#
# & DIAGNOSTICS
#
# A PreventiNe Life Care enterprise
#
#
#
# ; ; 20 Year(s) 0 Months(s) 0
# Name: DEEPA MUKHARJEE Age/Gender: Day(s)/Female
# Referred By: BHARAT AGARWAL Client Name: DER MED CLINIC
# Collection Date: 29-09-2019 11:03:00 Report Release Date: 29-09-2019
#
# Pine tee Tain Observed Value Reference Range
#
#
#
# Thyroid Profile - Total T3,Total T4,TSH (TFT)
#
# ] Total T3 66.57 60 - 200 ng/dL
# Serum, Method: CLIA
#
# 2 Total T4 8.21 4.5 - 12.0 ug/dL
# Serum, Method: CLIA
#
# 3 TSH (Thyroid Stimulating Hormone) 1.811 0.35 - 5.5 ulU/ml
# Serum, Method: CLIA
#
# Interpretation
#
# 1. Triodothyronine (T3) is produced by the thyroid gland and along with thyroxine (T4) help control the rate at which the body
# uses energy.Elevated T3 denote hyperthyroidism while low levels indicate hypothyroidism.
#
# 2.The most common causes of thyroid dysfunction are related to autoimmune disorders. Graves disease causes hyperthyroidism,
# but it can also be caused by thyroiditis, thyroid cancer, and excessive production of TSH. Total T3 is used to assess thyroid
# function.
#
# 3. Elevated T4 levels may indicate hyperthyroidism. They may also indicate other thyroid problems, such as thyroiditis or toxic
# multinodular goiter. Abnormally low levels of T4 may indicate: dietary issues, such as fasting, malnutrition, or an iodine
# deficiency, medications that affect protein levels, hypothyroidism, illness.
#
# 4. Thyroid-stimulating hormone (TSH) stimulates the production and release of T4 (primarily) and T3. They help control the
# rate at which the body uses energy and are regulated by a feedback system. Most of the T4 circulates in the blood bound to
# protein, while a small percentage is free (not bound).
#
# 5. Thyroid hormone status during pregnancy:
#
# 01-25 71-175 65-101
#
# 02:30 91-195 75-103
# 03:3. 104-182 63:9.
#
#
#
# * The analyte is not in the lab scope. g :
#
# CRM No "1210495 ° De OH a
#
# Sample Received Time: 29-09-2019 11:08:26 Authorized Signatory Authorized Signatory
#
# Report Release Date: 29-09-2019 Dr. Dina Abhani Dr. Mahesh Hampe
#
# Patient Name: DEEPA MUKHARJEE DCP, DNB (Pathology) MD (Biochemistry) Page 4 of 5
#
# Patient ID: 1210495
# To view your report, log in www.preventine.org/reports. Feed your Patient ID to download your report.0000001210495
#
# GENERAL DIAGNOSTICS
# Preventine Lifecare Pvt. Ltd.
# RPT House, Plot No. 6, Sec-24,
#
# Turbhe, Navi Mumbai-400705,
# Phone No: 022-4045-0000
#
# Name: DEEPA MUKHARJEE
# Referred By: BHARAT AGARWAL
# Collection Date: 29-09-2019 11:03:00
#
# Sees oecell|
#
# & DIAGNOSTICS
#
# A PreventiNe Life Care enterprise
#
#
#
# ; 20 Year(s) 0 Months(s) 0
# Age/Gender: Day(s)/Female
# Client Name: DER MED CLINIC
# Report Release Date: 29-09-2019
#
# Observed Value
#
#
#
# Investigation
#
# 1 Glucose (Random)
#
# Fluoride Plasma, Method: Hexokinase
#
# Interpretation
#
# Reference Range
#
# 90.2 Normal : 79 - 140
# Pre - Diabetes: 141 - 200
#
# Diabetes: > 200
#
# mg/dL
#
# Glucose is the primary energy source for the body's cells and the only energy source for the brain and nervous system.High
# levels of glucose most frequently indicate diabetes, but many other diseases and conditions can also cause elevated blood
# glucose. Hypoglycemia is characterized by a drop in blood glucose to a level where first it causes nervous system symptoms
# (sweating, palpitations, hunger, trembling, and anxiety), then begins to affect the brain (causing confusion, hallucinations,
# blurred vision, and sometimes even coma and death).
#
# * The analyte is not in the lab scope.
# CRM No :1210495
#
# Sample Received Time: 29-09-2019 11:08:26
# Report Release Date: 29-09-2019
#
# Patient Name: DEEPA MUKHARJEE
# Patient ID: 1210495
#
# End Of Report
#
# Er out
#
# Authorized Signatory Authorized Signatory
# Dr. Dina Abhani Dr. Mahesh Hampe
# DCP, DNB (Pathology) MD (Biochemistry) Page 5 of 5
#
# To view your report, log in www.preventine.org/reports. Feed your Patient ID to download your report.
# Vitals Only
# ['0', '77.6', '0', '0', '0', '5.28', '41.0', '282.0', '5.1', '1.811', '0', '0', '0', '0']
